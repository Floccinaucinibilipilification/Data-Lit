# %% [markdown]
# <a href="https://colab.research.google.com/github/Floccinaucinibilipilification/Data-Lit/blob/master/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## 1. Select a dataset
# The [Pokeman](https://www.kaggle.com/abcsds/pokemon) dataset seems most interesting to me among the most voted datasets on Kaggle.

# %%
from google.colab import files
uploaded = files.upload()
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-75ffd04f-0b07-4a3e-a48c-86bb75b0794b" name="files[]" multiple disabled />
#      <output id="result-75ffd04f-0b07-4a3e-a48c-86bb75b0794b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets list -h
# Out:
# usage: kaggle datasets list [-h] [--sort-by SORT_BY] [--size SIZE]
#                             [--file-type FILE_TYPE] [--license LICENSE_NAME]
#                             [--tags TAG_IDS] [-s SEARCH] [-m] [--user USER]
#                             [-p PAGE] [-v]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --sort-by SORT_BY     Sort list results. Default is 'hottest'. Valid options are 'hottest', 'votes', 'updated', and 'active'
#   --size SIZE           Search for datasets of a specific size. Default is 'all'. Valid options are 'all', 'small', 'medium', and 'large'
#   --file-type FILE_TYPE
#                         Search for datasets with a specific file type. Default is 'all'. Valid options are 'all', 'csv', 'sqlite', 'json', and 'bigQuery'. Please note that bigQuery datasets cannot be downloaded
#   --license LICENSE_NAME
#                         Search for datasets with a specific license. Default is 'all'. Valid options are 'all', 'cc', 'gpl', 'odb', and 'other'
#   --tags TAG_IDS        Search for datasets that have specific tags. Tag list should be comma separated
#   -s SEARCH, --search SEARCH
#                         Term(s) to search for
#   -m, --mine            Display only my items
#   --user USER           Find public datasets owned by a specific user or organization
#   -p PAGE, --page PAGE  Page number for results paging. Page size is 20 by default
#   -v, --csv             Print results in CSV format (if not set print in table format)

# %%
# !kaggle datasets list --file-type csv --sort-by votes
# Out:
# ref                                           title                                                size  lastUpdated          downloadCount
# --------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# mlg-ulb/creditcardfraud                       Credit Card Fraud Detection                          66MB  2018-03-23 01:17:27         102590
# tmdb/tmdb-movie-metadata                      TMDB 5000 Movie Dataset                               9MB  2017-09-28 01:09:12          82122
# zynicide/wine-reviews                         Wine Reviews                                         51MB  2017-11-27 17:08:04          48812
# START-UMD/gtd                                 Global Terrorism Database                            28MB  2018-09-10 18:22:18          40315
# lava18/google-play-store-apps                 Google Play Store Apps                                2MB  2019-02-03 13:55:47          41210
# mczielinski/bitcoin-historical-data           Bitcoin Historical Data                             111MB  2018-11-13 19:30:01          34182
# datasnaek/youtube-new                         Trending YouTube Video Statistics                   199MB  2018-11-20 16:57:05          30393
# mehdidag/black-friday                         Black Friday                                          5MB  2018-07-25 20:49:48          32085
# uciml/iris                                    Iris Species                                          4KB  2016-09-27 07:38:05          49728
# abcsds/pokemon                                Pokemon with stats                                   15KB  2016-08-29 06:01:43          27582
# worldbank/world-development-indicators        World Development Indicators                        385MB  2017-05-01 17:50:44          31932
# kiva/data-science-for-good-kiva-crowdfunding  Data Science for Good: Kiva Crowdfunding             42MB  2018-03-02 20:20:57          10892
# kaggle/kaggle-survey-2018                     2018 Kaggle ML & DS Survey                            4MB  2018-11-03 22:35:07           7735
# unsdsn/world-happiness                        World Happiness Report                               29KB  2017-06-14 20:41:45          52958
# rounakbanik/the-movies-dataset                The Movies Dataset                                  228MB  2017-11-10 02:40:38          36474
# wendykan/lending-club-loan-data               Lending Club Loan Data                              240MB  2016-05-02 21:41:52          42251
# aaron7sun/stocknews                           Daily News for Stock Market Prediction                6MB  2016-08-25 16:56:51          18899
# kaggle/kaggle-survey-2017                     Kaggle Machine Learning & Data Science Survey 2017    4MB  2017-10-27 22:03:03          14369
# ronitf/heart-disease-uci                      Heart Disease UCI                                     3KB  2018-06-25 11:33:56          14580
# uciml/breast-cancer-wisconsin-data            Breast Cancer Wisconsin (Diagnostic) Data Set        48KB  2016-09-25 10:49:04          38908

# %%
# !kaggle datasets download abcsds/pokemon
# Out:
# pokemon.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip pokemon.zip
# !ls
# Out:
# Archive:  pokemon.zip
# replace Pokemon.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Pokemon.csv
# Pokemon.csv  pokemon.zip  sample_data

# %%
import pandas as pd
pokemon = pd.read_csv('Pokemon.csv')
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.describe(include='all')
# Out:
#                  #       Name Type 1  Type 2      Total          HP  \
# count   800.000000        800    800     414  800.00000  800.000000
# unique         NaN        800     18      18        NaN         NaN
# top            NaN  Pachirisu  Water  Flying        NaN         NaN
# freq           NaN          1    112      97        NaN         NaN
# mean    362.813750        NaN    NaN     NaN  435.10250   69.258750
# std     208.343798        NaN    NaN     NaN  119.96304   25.534669
# min       1.000000        NaN    NaN     NaN  180.00000    1.000000
# 25%     184.750000        NaN    NaN     NaN  330.00000   50.000000
# 50%     364.500000        NaN    NaN     NaN  450.00000   65.000000
# 75%     539.250000        NaN    NaN     NaN  515.00000   80.000000
# max     721.000000        NaN    NaN     NaN  780.00000  255.000000
#
#             Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count   800.000000  800.000000  800.000000  800.000000  800.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     79.001250   73.842500   72.820000   71.902500   68.277500
# std      32.457366   31.183501   32.722294   27.828916   29.060474
# min       5.000000    5.000000   10.000000   20.000000    5.000000
# 25%      55.000000   50.000000   49.750000   50.000000   45.000000
# 50%      75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     100.000000   90.000000   95.000000   90.000000   90.000000
# max     190.000000  230.000000  194.000000  230.000000  180.000000
#
#         Generation Legendary
# count    800.00000       800
# unique         NaN         2
# top            NaN     False
# freq           NaN       735
# mean       3.32375       NaN
# std        1.66129       NaN
# min        1.00000       NaN
# 25%        2.00000       NaN
# 50%        3.00000       NaN
# 75%        5.00000       NaN
# max        6.00000       NaN

# %% [markdown]
# ## 2. Pose a question
# What characteristics are associated with being Legendary?

# %% [markdown]
# ## 3. Answer the question

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (9,6)

# %% [markdown]
# #### Pokemon Type
# According to the plots below, these three types of Pokemon are most likely to be Legendary:
#  - Flying
#  - Dragon
#  - Psychic

# %%
sns.countplot(pokemon['Type 1'],hue=pokemon['Legendary'], palette='coolwarm')
plt.xticks(rotation=45)
plt.title('Pokemon Counts by Legendary')
plt.xlabel('Pokemon Type 1')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])
# Text(0, 0.5, 'Count')

# %%
sns.countplot(pokemon['Type 2'],hue=pokemon['Legendary'], palette='coolwarm')
plt.xticks(rotation=45)
plt.title('Pokemon Counts by Legendary')
plt.xlabel('Pokemon Type 2')
plt.ylabel('Count')
plt.legend(loc=1, title='Legendary')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ### Pokemon Generation
# Being Generation 3 has the highest probability (11.25%) to be Legendary.

# %%
pd.crosstab(pokemon.Generation, pokemon.Legendary, margins=True)
# Out:
# Legendary   False  True  All
# Generation
# 1             160     6  166
# 2             101     5  106
# 3             142    18  160
# 4             108    13  121
# 5             150    15  165
# 6              74     8   82
# All           735    65  800

# %%
pokemon.groupby('Generation')['Legendary'].mean()
# Out:
# Generation
# 1    0.036145
# 2    0.047170
# 3    0.112500
# 4    0.107438
# 5    0.090909
# 6    0.097561
# Name: Legendary, dtype: float64

# %% [markdown]
# ### Pokemon Total Strength
# Overall, Legendary Pokemons have higher Total Strength.

# %%
plt.hist(pokemon[pokemon.Legendary==True]['Total'], color='r', label='True')
plt.hist(pokemon[pokemon.Legendary==False]['Total'], color='b', label='False', alpha=0.7, bins=20)
plt.legend(title='Legendary', loc=1)
plt.xlabel('Pokemon Total Strength')
plt.ylabel('Pokemon Counts')
# Out:
# Text(0, 0.5, 'Pokemon Counts')

# %% [markdown]
# ### Pokemon Separate Strength Points
# The separate strength points all seem to contribute to being Legendary to some extent, but it's hard to tell which one(s) are the most important one(s).

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon_power = pokemon[['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
sum(pokemon_power.drop('Total', axis=1).sum(axis=1) == pokemon_power.Total) # sanity check
# Out:
# 800

# %%
pokemon_power = pokemon_power.drop('Total', axis=1)
pokemon_power['Legendary'] = pokemon.Legendary
pokemon_power.head()
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 0  45      49       49       65       65     45      False
# 1  60      62       63       80       80     60      False
# 2  80      82       83      100      100     80      False
# 3  80     100      123      122      120     80      False
# 4  39      52       43       60       50     65      False

# %%
sns.pairplot(pokemon_power, hue='Legendary',palette='coolwarm')

# %% [markdown]
# #### Dimensionality Reduction
# Apply PCA to reduce dimension to 2 dimensions.
# The first principal component being greater than 2 indicates higher probability of being Legendary.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
x = pokemon[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
x = StandardScaler().fit_transform(x)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
pca = PCA(n_components=2)
pc = pca.fit_transform(x)
pca.explained_variance_ratio_
pcDF = pd.DataFrame(data=pc, columns=['pc1', 'pc2'])

# %%
pcDF['Legendary'] = pokemon['Legendary']

# %%
sns.lmplot(x='pc1', y='pc2', hue='Legendary', data=pcDF, fit_reg=False)

# %% [markdown]
# ### Wrap up
# Pokemon Type, Generation, and Strength are associated with being Legendary.
